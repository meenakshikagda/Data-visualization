# %%
# Vega dataset (Seattle weather)

from altair import Chart
import pandas as pd

# %%
from vega_datasets import data

df = data.seattle_weather()
df.head()
# Out:
#         date  precipitation  temp_max  temp_min  wind  weather
# 0 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2 2012-01-03            0.8      11.7       7.2   2.3     rain
# 3 2012-01-04           20.3      12.2       5.6   4.7     rain
# 4 2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
df.describe()
# Out:
#        precipitation     temp_max     temp_min         wind
# count    1461.000000  1461.000000  1461.000000  1461.000000
# mean        3.029432    16.439083     8.234771     3.241136
# std         6.680194     7.349758     5.023004     1.437825
# min         0.000000    -1.600000    -7.100000     0.400000
# 25%         0.000000    10.600000     4.400000     2.200000
# 50%         0.000000    15.600000     8.300000     3.000000
# 75%         2.800000    22.200000    12.200000     4.000000
# max        55.900000    35.600000    18.300000     9.500000

# %%
import altair as alt
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
Chart(df).mark_point().encode(
    x = 'date:N',
    y='precipitation:Q'
)

# %%
Chart(df).mark_bar().encode(
    x = 'date:N',
    y='mean(precipitation):Q'
)

# %%
df2 = df.groupby('date', as_index=False, sort=False)['precipitation'].mean()

# %%
df2.head()
# Out:
#         date  precipitation
# 0 2012-01-01            0.0
# 1 2012-01-02           10.9
# 2 2012-01-03            0.8
# 3 2012-01-04           20.3
# 4 2012-01-05            1.3

# %%
df2.describe()
# Out:
#        precipitation
# count    1461.000000
# mean        3.029432
# std         6.680194
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.800000
# max        55.900000

# %%
df['year'] = pd.DatetimeIndex(df['date']).year

# %%
df.head()
# Out:
#         date  precipitation  temp_max  temp_min  wind  weather  year
# 0 2012-01-01            0.0      12.8       5.0   4.7  drizzle  2012
# 1 2012-01-02           10.9      10.6       2.8   4.5     rain  2012
# 2 2012-01-03            0.8      11.7       7.2   2.3     rain  2012
# 3 2012-01-04           20.3      12.2       5.6   4.7     rain  2012
# 4 2012-01-05            1.3       8.9       2.8   6.1     rain  2012

# %%
df['month'] = pd.DatetimeIndex(df['date']).month

# %%
df.head()
# Out:
#         date  precipitation  temp_max  temp_min  wind  weather  year  month
# 0 2012-01-01            0.0      12.8       5.0   4.7  drizzle  2012      1
# 1 2012-01-02           10.9      10.6       2.8   4.5     rain  2012      1
# 2 2012-01-03            0.8      11.7       7.2   2.3     rain  2012      1
# 3 2012-01-04           20.3      12.2       5.6   4.7     rain  2012      1
# 4 2012-01-05            1.3       8.9       2.8   6.1     rain  2012      1

# %%
df.head(n=50)
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather  year  month
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle  2012      1
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain  2012      1
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain  2012      1
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain  2012      1
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain  2012      1
# 5  2012-01-06            2.5       4.4       2.2   2.2     rain  2012      1
# 6  2012-01-07            0.0       7.2       2.8   2.3     rain  2012      1
# 7  2012-01-08            0.0      10.0       2.8   2.0      sun  2012      1
# 8  2012-01-09            4.3       9.4       5.0   3.4     rain  2012      1
# 9  2012-01-10            1.0       6.1       0.6   3.4     rain  2012      1
# 10 2012-01-11            0.0       6.1      -1.1   5.1      sun  2012      1
# ...

# %%
df2 = df.groupby('year', as_index=False, sort=False)['precipitation'].mean()

# %%
df2.describe()
# Out:
#               year  precipitation
# count     4.000000       4.000000
# mean   2013.500000       3.029213
# std       1.290994       0.519998
# min    2012.000000       2.268493
# 25%    2012.750000       2.907945
# 50%    2013.500000       3.235411
# 75%    2014.250000       3.356679
# max    2015.000000       3.377534

# %%
df2
# Out:
#    year  precipitation
# 0  2012       3.349727
# 1  2013       2.268493
# 2  2014       3.377534
# 3  2015       3.121096

# %%
df2 = df.groupby(['year', 'month'], as_index=False, sort=False)['precipitation'].mean()

# %%
df2.describe()
# Out:
#               year      month  precipitation
# count    48.000000  48.000000      48.000000
# mean   2013.500000   6.500000       3.033535
# std       1.129865   3.488583       2.288768
# min    2012.000000   1.000000       0.000000
# 25%    2012.750000   3.750000       1.225806
# 50%    2013.500000   6.500000       2.633871
# 75%    2014.250000   9.250000       4.841310
# max    2015.000000  12.000000       9.177419

# %%
Chart(df2).mark_point().encode(
    x = 'month:N',
    y='precipitation:Q',
    color='year:N'
)

# %%
Chart(df2).mark_bar().encode(
    x = 'month:N',
    y='precipitation:Q',
    color='year:N'
)

# %%
Chart(df2).mark_bar().encode(
    x = 'month:N',
    y='precipitation:Q',
    color='year:N'
).properties(
    width=180,
    height=180
)

# %%
df2_wind = df.groupby(['year', 'month'], as_index=False, sort=False)['wind'].mean()

# %%
Chart(df2_wind).mark_bar().encode(
    x = 'month:N',
    y='wind:Q',
    color='year:N'
).properties(
    width=180,
    height=180
)

# %%
df2_temp_max = df.groupby(['year', 'month'], as_index=False, sort=False)['temp_max'].mean()

# %%
Chart(df2_temp_max).mark_bar().encode(
    x = 'month:N',
    y='temp_max:Q',
    color='year:N'
).properties(
    width=180,
    height=180
)

# %%
df2_temp_min = df.groupby(['year', 'month'], as_index=False, sort=False)['temp_min'].mean()

# %%
Chart(df2_temp_min).mark_bar().encode(
    x = 'month:N',
    y='temp_min:Q',
    color='year:N'
).properties(
    width=180,
    height=180
)

# %%
temp_min = Chart(df2_temp_min, title="Seatle minimum temprature avg").mark_bar().encode(
    x = 'month:N',
    y='temp_min:Q',
    color='year:N'
)

temp_max = Chart(df2_temp_max, title="Seatle maximum temprature avg").mark_bar().encode(
    x = 'month:N',
    y='temp_max:Q',
    color='year:N'
)


wind = Chart(df2_wind, title="Seatle wind avg").mark_bar().encode(
    x = 'month:N',
    y='wind:Q',
    color='year:N'
)

precipitation = Chart(df2, title="Seatle precipitation avg").mark_bar().encode(
    x = 'month:N',
    y='precipitation:Q',
    color='year:N'
)
(wind | precipitation) & (temp_max | temp_min)

# %%
precipitation = alt.Chart(df2, 
                      title="Seatle precipiation").mark_bar().encode(
    x = 'month:N',
    y='precipitation:Q',
    color='year:N'
)
                      
precipitation

# %%
from vega_datasets import data
import altair as alt

source = data.us_employment()
presidents = pd.DataFrame([
    {
        "start": "2006-01-01",
        "end": "2009-01-19",
        "president": "Bush"
    },
    {
        "start": "2009-01-20",
        "end": "2015-12-31",
        "president": "Obama"
    }
])

bars = alt.Chart(
    source,
    title="The U.S. employment crash during the Great Recession"
).mark_bar().encode(
    x=alt.X("month:T", title=""),
    y=alt.Y("nonfarm_change:Q", title="Change in non-farm employment (in thousands)"),
    color=alt.condition(
        alt.datum.nonfarm_change > 0,
        alt.value("steelblue"),
        alt.value("orange")
    )
)

rule = alt.Chart(presidents).mark_rule(
    color="black",
    strokeWidth=2
).encode(
    x='end:T'
).transform_filter(alt.datum.president == "Bush")

text = alt.Chart(presidents).mark_text(
    align='left',
    baseline='middle',
    dx=7,
    dy=-135,
    size=11
).encode(
    x='start:T',
    x2='end:T',
    text='president',
    color=alt.value('#000000')
)

(bars + rule + text).properties(width=600)
